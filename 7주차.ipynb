# %% [markdown]
# <a href="https://colab.research.google.com/github/minzx23/kk/blob/main/7%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
x=np.arange(-10,10,0.1)
f=1/(1+np.exp(-x))
ax.plot(x,f)
ax.set_xticks(range(-10,10))
ax.set_yticks(range(0,2))
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
x=np.arange(-10,10,0.1)
W=np.arange(0.5,3,0.5)
for w in W:
    f=1/(1+np.exp(-x*w))
    ax.plot(x,f)
ax.set_xticks(range(-10,10))
ax.set_yticks(range(0.2))
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-0cb26cbd9d91> in <cell line: 11>()
#       9     ax.plot(x,f)
#      10 ax.set_xticks(range(-10,10))
# ---> 11 ax.set_yticks(range(0.2))
#      12 ax.set_xlabel('x')
#      13 ax.set_ylabel('f(x)')
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
import numpy as np
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
x=np.arange(-10,10,0.1)
w=0.5
B=np.arange(-2,2,0.5)
for b in B:
    f=1/(1+np.exp(-x*w+b))
    ax.plot(x,f)
ax.set_xticks(range(-10,10))
ax.set_yticks(range(0,2))
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
plt.show()
